# %% [markdown]
# # Dataset Description

# %% [markdown]
# <b> The MPG dataset is consisting of manufacturing details of cars in different origins with a different cars this information grabed from machine learning repository using seaborn package for testing purpose.  </b> <br> <br>
# <b> The data city-cycle fuel consumption in miles per gallon to be analyzed in terms of 3 multivalued discrete and 5 continuous attributes. </b>

# %% [markdown]
# # Environment set-up

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

# %% [markdown]
# # Data Wrangling

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset("mpg")

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Columns Description

# %% [markdown]
# <b> Mpg:</b>           Miles per galon of fuel (continuous variable). <br>
# <b> Cylinders:</b>     Number of engine cylinders (multi-valued discrete variable). <br>
# <b> Displacement:</b>  Continuous variable.  <br>
# <b> Horsepower:</b>    The power produced by engine to move the car (continuous variable). <br>
# <b> Weight:</b>        Car weight (continuous variable). <br>
# <b> Acceleration:</b>  The acceleration of an engine can get per second (continuous variable). <br>
# <b> Model year:</b>    Car released year from 1970 to 1982 (multi-valued discrete variable). <br>
# <b> Origin:</b>        Car manufacturing places (1 -> USA, 2 -> Europe, 3 -> Asia) (multi-valued discrete variable). <br>
# <b> Car name:</b>      Car model name (unique for each instance). <br>

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
len(df.columns)
# Out:
# 9

# %%
len(df.describe().columns)
# Out:
# 7

# %%
len(df.columns)-len(df.describe().columns)
# Out:
# 2

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
df.horsepower.unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#         nan, 100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,
#         65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137.,
#        158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,
#         78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,
#         81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,
#         48.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
list(df.columns)
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year',
#  'origin',
#  'name']

# %% [markdown]
# # Two Continous variables

# %%
for col in df.columns:
    sns.scatterplot(x=col,y='mpg',data=df)
    plt.show()

# %% [markdown]
# <b>Findings and Insights</b> <br> <br>
# <b>1</b>. The mass per gallon here starting line for the along 45 degree angle <br>
# <b>2</b>. The cylinders realy relationship here <br>
#           (i) The cylinder along you know 8 cylinder the 5 cylinder and four and three cylinder <br>
#           (ii) 3 cylinder cars that have poorer mpg than some 4 cylinder cars <br>
# <b>3</b>. Inverse relationship between the displacement the size of engine and the mass per gallon <br>
# <b>4</b>. The similar with the displacement and horsepower and weight this three columns is similar and highly corelated <br>
# <b>5</b>. The acceleration is positive correlation <br>
# <b>6</b>. The modal year mass per gallon improves <br>
#           (i)1970 all the way to 1982 is mass per gallon is improves <br>
# <b>7</b>. Cylinder is negative correlation <br>
# <b>8</b>. Acceleration is a possitive correlation

# %%
df.corr('spearman')
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.821864     -0.855692   -0.853616 -0.874947
# cylinders    -0.821864   1.000000      0.911876    0.816188  0.873314
# displacement -0.855692   0.911876      1.000000    0.876171  0.945986
# horsepower   -0.853616   0.816188      0.876171    1.000000  0.878819
# weight       -0.874947   0.873314      0.945986    0.878819  1.000000
# acceleration  0.438677  -0.474189     -0.496512   -0.658142 -0.404550
# model_year    0.573469  -0.335012     -0.305257   -0.389498 -0.277015
#
#               acceleration  model_year
# mpg               0.438677    0.573469
# cylinders        -0.474189   -0.335012
# displacement     -0.496512   -0.305257
# horsepower       -0.658142   -0.389498
# weight           -0.404550   -0.277015
# acceleration      1.000000    0.274632
# model_year        0.274632    1.000000

# %%
df.corr('kendall')
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.686477     -0.679847   -0.679166 -0.694006
# cylinders    -0.686477   1.000000      0.794854    0.686146  0.735481
# displacement -0.679847   0.794854      1.000000    0.718471  0.800508
# horsepower   -0.679166   0.686146      0.718471    1.000000  0.703730
# weight       -0.694006   0.735481      0.800508    0.703730  1.000000
# acceleration  0.301096  -0.367194     -0.352110   -0.488239 -0.268619
# model_year    0.413661  -0.273742     -0.218920   -0.277831 -0.196863
#
#               acceleration  model_year
# mpg               0.301096    0.413661
# cylinders        -0.367194   -0.273742
# displacement     -0.352110   -0.218920
# horsepower       -0.488239   -0.277831
# weight           -0.268619   -0.196863
# acceleration      1.000000    0.196024
# model_year        0.196024    1.000000

# %% [markdown]
# # 1 Continous variable and 1 class variable

# %% [markdown]
#  <b>Model year vs Mpg</b>

# %%
plt.figure(figsize=(5, 4))
sns.barplot(df['model_year'],df['mpg'])
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# <b> Finding and Insights </b> <br>
# <b>1</b>. Model_year 80 has highest mpg. <br>
# <b>2</b>. Modal_year 73 has lowest mpg. <br>
# <b>3</b>. In a xlabel is a model_year and ylable will be prasent in mpg

# %% [markdown]
# # Two class variables

# %% [markdown]
# <b>Origin vs Cylinders</b>

# %%
df1=pd.crosstab(df['cylinders'], df['origin'])
sns.heatmap(df1, annot=True, cmap='viridis', linecolor='r', linewidth=2, fmt='g')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='cylinders'>

# %% [markdown]
# <b> Insights </b> <br>
# <b>1</b>. Japan only 4 or 3 or 6 cylinders. <br>
# <b>2</b>  Usa only 4,8 or 6 cylinders.<br>
# <b>3</b>  The usa origin at 103 percentile as per other origins

# %% [markdown]
# # class variables

# %%
df['model_year'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='model_year'>

# %% [markdown]
# <b>1</b>. The highest percentage was 10% in the model year 73. <br>
# <b>2</b>.  At least 7% of the cars from each model year are present

# %%
df['origin'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='origin'>

# %% [markdown]
# <b>Insights</b> <br>
# <b>1</b>. 63% of usa and japan both produce 20% and 18% of all cars

# %% [markdown]
# # Continous variables

# %%
plt.hist(df['displacement'],alpha=0.5,bins=15)
# Out:
# (array([56., 82., 58., 26.,  5., 13., 32., 28.,  0., 42., 27.,  4., 16.,
#          3.,  6.]),
#  array([ 68. ,  93.8, 119.6, 145.4, 171.2, 197. , 222.8, 248.6, 274.4,
#         300.2, 326. , 351.8, 377.6, 403.4, 429.2, 455. ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# <b>Finding Insights</b> <br>
#
# <b>1</b> Increasing displacement number of decreasing count <br>
# <b>2</b>. No cars between 275 and 300 displacement.<br>
# <b>3</b>. Smallest pickup displacement in the range of 425 to 450. <br>
# <b>4</b>. There is only one peak value at 100, the graph is unimodal.

# %%
plt.hist(df['weight'],alpha=0.9,bins=25)
# Out:
# (array([ 2., 17., 30., 38., 34., 21., 23., 27., 17., 25., 14., 18., 20.,
#         11., 14., 13., 10., 14., 11., 15.,  8.,  7.,  3.,  5.,  1.]),
#  array([1613.  , 1754.08, 1895.16, 2036.24, 2177.32, 2318.4 , 2459.48,
#         2600.56, 2741.64, 2882.72, 3023.8 , 3164.88, 3305.96, 3447.04,
#         3588.12, 3729.2 , 3870.28, 4011.36, 4152.44, 4293.52, 4434.6 ,
#         4575.68, 4716.76, 4857.84, 4998.92, 5140.  ]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# <b>Finding Insights</b> <br>
#
# <b>1</b>. 37 cars must be between 2177.32 and 2318.4 <br>
# <b>2</b>  Smallest pick displacement in the range of 4998.92 to 5140. <br>
# <b>3</b>. Only 10 vehicles weigh 4857 pounds or more.
